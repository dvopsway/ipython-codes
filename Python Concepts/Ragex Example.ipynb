# %%
#Example of using ragex in python

# %%
import re
#line = "Output:\nECHO is on.\r\n**********HTNEngine-05/26/2015-2**********************************************\n00000 \n**********************************************************************************************************\n. \n**********HTNEngine-05/26/2015-4**********************************************\n00000 \n**********************************************************************************************************\n. \n**********HTNEngine-06/01/2015-5**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-06/03/2015-6**********************************************\nttt \n**********************************************************************************************************\n. \n**********HTNEngine-06/05/2015-7**********************************************\ner \n**********************************************************************************************************\n. \n**********HTNEngine-06/05/2015-8**********************************************\nterr \n**********************************************************************************************************\n. \n**********HTNEngine-06/08/2015-9**********************************************\nUtility Build Out Put Testing \n**********************************************************************************************************\n. \n**********HTNEngine-06/12/2015-10**********************************************\nTest  \n**********************************************************************************************************\n. \n**********HTNEngine-06/16/2015-11**********************************************\nChanges for auto and common build from jenkins for B2C and TLDs \n**********************************************************************************************************\n. \n**********HTNEngine-06/16/2015-12**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-06/16/2015-13**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-06/16/2015-14**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-06/16/2015-15**********************************************\nch \n**********************************************************************************************************\n. \n**********HTNEngine-06/16/2015-16**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-06/16/2015-17**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-06/16/2015-18**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-06/16/2015-19**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-06/17/2015-20**********************************************\nHRY \n**********************************************************************************************************\n. \n**********HTNEngine-06/19/2015-21**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-06/22/2015-23**********************************************\nPixel Tracking improved final \n**********************************************************************************************************\n. \n**********HTNEngine-06/22/2015-24**********************************************\nPixel Tracking improved with base 64 fix \n**********************************************************************************************************\n. \n**********HTNEngine-06/24/2015-27**********************************************\nbase 64 error fix(random issue) \n**********************************************************************************************************\n. \n**********HTNEngine-07/07/2015-28**********************************************\ntest \n**********************************************************************************************************\n. \n**********HTNEngine-07/07/2015-29"
line = "Output:\nECHO is on.\r\n********* Release Details ********* \r\n BUILD NUMBER=142 \r\n APPLICATION NAME= HTNEngine \r\n USER EMAIL =Pankaj.Goyal@makemytrip.com \r\n DATE = Fri 08/21/2015  \r\n"

htncount = re.findall(r'HTNEngine-\d{0,9}\/\d{0,9}\/\d{0,9}',line)
buildversion = re.findall(r'BUILD NUMBER\s*\=\s*\d{0,9}',line)
appname = re.findall(r'APPLICATION NAME\s*\=\s*\w+',line)
user_contact = re.findall(r'USER EMAIL\s*\=\s*\w+\.\w+\@\w+\.\w+',line)
build_date = re.findall(r'DATE\s*\=\s*\w+\s*\d{0,9}\/\d{0,9}\/\d{0,9}',line)

#print htncount
print buildversion[0].split("=")[1].strip(" ")
print appname[0].split("=")[1].strip(" ")
print user_contact[0].split("=")[1].strip(" ")
print build_date[0].split("=")[1].strip(" ")
# Out:
# 142
# HTNEngine
# Pankaj.Goyal@makemytrip.com
# Fri 08/21/2015
